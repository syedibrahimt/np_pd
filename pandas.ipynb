# %% [markdown]
# <a href="https://colab.research.google.com/github/syedibrahimt/np_pd/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
my_data_set ={
    'cars': ['maruti', 'hyundai', 'tata', 'mahendra'],
    'performance': [80, 85, 70, 80]
}

# %%
my_var=pd.DataFrame(my_data_set)

# %%
my_var
# Out:
#        cars  performance
# 0    maruti           80
# 1   hyundai           85
# 2      tata           70
# 3  mahendra           80

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
temp_list = ['a','b','c','d','e']
temp_series = pd.Series(temp_list)

# %%
temp_series
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
temp_series[1]
# Out:
# 'b'

# %%
calories_burnt = {'day1': 200, 'day2': 230, 'day3': 221, 'day4': 250, 'day5': 225}
series_calories = pd.Series(calories_burnt)

# %%
series_calories
# Out:
# day1    200
# day2    230
# day3    221
# day4    250
# day5    225
# dtype: int64

# %% [markdown]
# # Series is like a column but dataframe is the whole table

# %%
member_calories = {
    'names': ['syed', 'ibrahim', 'hakeem', 'afrin'],
    'calories_burnt': [200, 250, 100, 200]
}
df_member_calories = pd.DataFrame(member_calories)
print(df_member_calories)
# Out:
#      names  calories_burnt
# 0     syed             200
# 1  ibrahim             250
# 2   hakeem             100
# 3    afrin             200

# %%
df_member_calories
# Out:
#      names  calories_burnt
# 0     syed             200
# 1  ibrahim             250
# 2   hakeem             100
# 3    afrin             200

# %%
df_member_calories.loc[0]
# Out:
# names             syed
# calories_burnt     200
# Name: 0, dtype: object

# %%
df_member_calories.loc[[0,2]]
# Out:
#     names  calories_burnt
# 0    syed             200
# 2  hakeem             100
